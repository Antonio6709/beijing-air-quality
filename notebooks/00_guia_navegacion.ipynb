# %% [markdown]
# # 00 - Guía del proyecto
#
# Este notebook sirve como índice y ruta de ejecución de la entrega.

# %% [markdown]
# ## Índice
# - [01 - Limpieza y unificación](./01_limpieza_y_unificacion.ipynb)
# - [02 - EDA y visualización](./02_eda_y_visualizacion.ipynb)
# - [03 - SQL y resumen ejecutivo](./03_sql_y_resumen_ejecutivo.ipynb)
# - [04 - Impacto normativo y riesgos](./04_impacto_normativo_y_riesgos.ipynb)

# %% [markdown]
# ## Orden recomendado de ejecución
# 1. Abrir 1_limpieza_y_unificacion.ipynb y ejecutar **Run All**.
# 2. Verificar que se genera data/processed/beijing_unified_cleaned.csv.
# 3. Abrir 2_eda_y_visualizacion.ipynb y ejecutar **Run All** para generar figuras en
# eports/.
# 4. Abrir 3_sql_y_resumen_ejecutivo.ipynb para análisis SQL + síntesis ejecutiva.
# 5. Abrir 4_impacto_normativo_y_riesgos.ipynb para narrativa de riesgos, cumplimiento regulatorio y mensajes de alto impacto.

# %%
from pathlib import Path

candidate_roots = [Path('.').resolve(), Path('..').resolve()]
project_root = next((p for p in candidate_roots if (p / 'data').exists() and (p / 'notebooks').exists()), None)
if project_root is None:
    raise FileNotFoundError('No se encontró la raíz del proyecto.')

expected_paths = [
    project_root / 'data' / 'raw',
    project_root / 'data' / 'processed',
    project_root / 'reports',
]
for p in expected_paths:
    print(f'{p}: {p.exists()}')
# Out:
# C:\data_sciences\GIT\beijing-air-quality\data\raw: True
# C:\data_sciences\GIT\beijing-air-quality\data\processed: True
# C:\data_sciences\GIT\beijing-air-quality\reports: True
