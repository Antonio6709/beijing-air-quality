# %% [markdown]
# # 1 Importación de librerías

# %%
import sys
from pathlib import Path

# Añadir raíz del proyecto al path para importar src/
project_root = Path('.').resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.data_processing import cargar_estaciones, construir_fecha, guardar_csv
from src.cleaning_utils import interpolar_nulos

import os

# %% [markdown]
# # 2 Carga de datos y unión

# %%
path = os.path.join('..', 'data', 'raw')
df = cargar_estaciones(path)

# %%
print(df.info())

# %%
print(df.isnull().sum())

# %% [markdown]
# # 4 Transformación y limpieza de datos

# %% [markdown]
# Tratamos fechas unificando en 'date' y borramos 'No'

# %%
df = construir_fecha(df)
df.head()

# %% [markdown]
# Utilizamos interpolate para no perder información y rellenar los datos faltantes

# %%
df = interpolar_nulos(df)

# %%
df.info()

# %% [markdown]
# # Guardamos la tabla unificada y limpia

# %%
guardar_csv(df, '../data/processed')
